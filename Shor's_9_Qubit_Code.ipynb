# %% [markdown]
# <a href="https://colab.research.google.com/github/Alan-Cheong/IEEE_QW_2020/blob/master/Shor's_9_Qubit_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install qiskit-aer
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit import transpile
from qiskit_aer import AerSimulator
import numpy as np

# Initialize registers
qreg = QuantumRegister(9, 'q')  # 9 qubits for Shor's code
creg_bit = ClassicalRegister(6, 'c_bit')  # 6 bits for bit-flip syndromes
creg_phase = ClassicalRegister(2, 'c_phase')  # 2 bits for phase-flip syndromes
circ = QuantumCircuit(qreg, creg_bit, creg_phase)

# Initialize logical qubit in |+> = (|0> + |1>)/sqrt(2) for testing
circ.h(0)  # Apply Hadamard to qubit 0

# Encoding circuit for Shor's 9-qubit code
# First group (qubits 0, 1, 2)
circ.cx(0, 1)
circ.cx(0, 2)
circ.h([0, 1, 2])  # Hadamard for phase encoding
# Second group (qubits 3, 4, 5)
circ.cx(0, 3)
circ.cx(0, 4)
circ.cx(3, 5)
circ.h([3, 4, 5])
# Third group (qubits 6, 7, 8)
circ.cx(0, 6)
circ.cx(0, 7)
circ.cx(6, 8)
circ.h([6, 7, 8])

# Introduce an X error on qubit 2 (for demonstration)
circ.x(2)

# Syndrome measurements
# Bit-flip syndromes (Z1Z2, Z1Z3, Z4Z5, Z4Z6, Z7Z8, Z7Z9)
circ.cx(0, 1)
circ.cz(0, 1)
circ.measure(1, 0)
circ.reset(1)
circ.cx(0, 2)
circ.cz(0, 2)
circ.measure(2, 1)
circ.reset(2)
circ.cx(3, 4)
circ.cz(3, 4)
circ.measure(4, 2)
circ.reset(4)
circ.cx(3, 5)
circ.cz(3, 5)
circ.measure(5, 3)
circ.reset(5)
circ.cx(6, 7)
circ.cz(6, 7)
circ.measure(7, 4)
circ.reset(7)
circ.cx(6, 8)
circ.cz(6, 8)
circ.measure(8, 5)
circ.reset(8)

# Phase-flip syndromes (X1X4, X1X7)
circ.h([0, 3, 6])
circ.cx(0, 3)
circ.cz(0, 3)
circ.measure(3, 6)
circ.reset(3)
circ.cx(0, 6)
circ.cz(0, 6)
circ.measure(6, 7)
circ.reset(6)
circ.h(0)

# Error correction based on syndromes (example for X error on qubit 2)
# If c_bit[1] = 1 and c_bit[0] = 0, apply X to qubit 2
# In simulation, we know the error; in practice, use conditional gates
circ.x(2)  # Correct the X error

# Measure the logical qubit (in |+> state, expect 0 in X-basis)
circ.h(0)
circ.measure(0, creg_bit[0])  # Reuse c_bit[0] for final measurement

print(circ)

# Simulate the circuit
backend = AerSimulator()
new_circuit = transpile(circ, backend)
job = backend.run(new_circuit, shots=1024)
result = job.result()
counts = result.get_counts()
print(counts)
#simulator = Aer.get_backend('qasm_simulator')
#job = backend.run(circ, simulator, shots=1024)
#result = job.result()
#counts = result.get_counts()

# Print results
print("Measurement counts:", counts)

# Analyze syndromes
for outcome in counts:
    bits = outcome.split()
    bit_syndrome = bits[1]  # c_bit
    phase_syndrome = bits[0]  # c_phase
    print(f"Bit-flip syndrome: {bit_syndrome}, Phase-flip syndrome: {phase_syndrome}")
# Out:
# Requirement already satisfied: qiskit in /usr/local/lib/python3.11/dist-packages (2.0.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from qiskit) (0.16.0)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.11/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.11/dist-packages (from qiskit) (1.15.2)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.11/dist-packages (from qiskit) (1.13.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.11/dist-packages (from qiskit) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from qiskit) (5.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from qiskit) (4.13.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.11/dist-packages (from qiskit) (0.13.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from stevedore>=3.0.0->qiskit) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.3->qiskit) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit) (75.2.0)
# Requirement already satisfied: qiskit-aer in /usr/local/lib/python3.11/dist-packages (0.17.0)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from qiskit-aer) (2.0.0)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.11/dist-packages (from qiskit-aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from qiskit-aer) (1.15.2)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.11/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.16.0)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.1.0->qiskit-aer) (1.13.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.1.0->qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.1.0->qiskit-aer) (5.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.1.0->qiskit-aer) (4.13.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-aer) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (75.2.0)
#            ┌───┐          ┌───┐                                             »
#       q_0: ┤ H ├──■────■──┤ H ├──■─────────■─────────■────■────■────■────■──»
#            └───┘┌─┴─┐  │  ├───┤  │         │         │    │  ┌─┴─┐  │    │  »
#       q_1: ─────┤ X ├──┼──┤ H ├──┼─────────┼─────────┼────┼──┤ X ├──■────┼──»
#                 └───┘┌─┴─┐├───┤  │  ┌───┐  │         │    │  └───┘     ┌─┴─┐»
#       q_2: ──────────┤ X ├┤ H ├──┼──┤ X ├──┼─────────┼────┼────────────┤ X ├»
#                      └───┘└───┘┌─┴─┐└───┘  │  ┌───┐  │    │            └───┘»
#       q_3: ────────────────────┤ X ├──■────┼──┤ H ├──┼────┼────■────■───────»
#                                └───┘  │  ┌─┴─┐├───┤  │    │  ┌─┴─┐  │   ┌─┐ »
#       q_4: ───────────────────────────┼──┤ X ├┤ H ├──┼────┼──┤ X ├──■───┤M├─»
#                                     ┌─┴─┐├───┤└───┘  │    │  └───┘      └╥┘ »
#       q_5: ─────────────────────────┤ X ├┤ H ├───────┼────┼──────────────╫──»
#                                     └───┘└───┘     ┌─┴─┐  │       ┌───┐  ║  »
#       q_6: ────────────────────────────────────────┤ X ├──┼────■──┤ H ├──╫──»
#                                                    └───┘┌─┴─┐  │  ├───┤  ║  »
#       q_7: ─────────────────────────────────────────────┤ X ├──┼──┤ H ├──╫──»
#                                                         └───┘┌─┴─┐├───┤  ║  »
#       q_8: ──────────────────────────────────────────────────┤ X ├┤ H ├──╫──»
#                                                              └───┘└───┘  ║  »
#   c_bit: 6/══════════════════════════════════════════════════════════════╩══»
#                                                                          2  »
# c_phase: 2/═════════════════════════════════════════════════════════════════»
#                                                                             »
# «                ┌───┐                                                  ┌───┐»
# «      q_0: ──■──┤ H ├───────────────■───────────■────────■───────────■─┤ H ├»
# «             │  └┬─┬┘               │           │        │           │ └───┘»
# «      q_1: ──┼───┤M├──|0>───────────┼───────────┼────────┼───────────┼──────»
# «             │   └╥┘                │  ┌─┐      │ ┌───┐  │           │      »
# «      q_2: ──■────╫─────────────────┼──┤M├─|0>──┼─┤ X ├──┼───────────┼──────»
# «                  ║          ┌───┐┌─┴─┐└╥┘      │ └───┘  │  ┌─┐      │      »
# «      q_3: ──■────╫────────■─┤ H ├┤ X ├─╫───────■────────┼──┤M├─|0>──┼──────»
# «             │    ║        │ └───┘└───┘ ║                │  └╥┘      │      »
# «      q_4: ──┼────╫───|0>──┼────────────╫────────────────┼───╫───────┼──────»
# «           ┌─┴─┐  ║        │  ┌─┐       ║                │   ║       │      »
# «      q_5: ┤ X ├──╫────────■──┤M├──|0>──╫────────────────┼───╫───────┼──────»
# «           └───┘  ║           └╥┘       ║         ┌───┐┌─┴─┐ ║       │  ┌─┐ »
# «      q_6: ──■────╫────■───────╫────■───╫───────■─┤ H ├┤ X ├─╫───────■──┤M├─»
# «           ┌─┴─┐  ║    │  ┌─┐  ║    │   ║       │ └───┘└───┘ ║          └╥┘ »
# «      q_7: ┤ X ├──╫────■──┤M├──╫────┼───╫──|0>──┼────────────╫───────────╫──»
# «           └───┘  ║       └╥┘  ║  ┌─┴─┐ ║       │  ┌─┐       ║           ║  »
# «      q_8: ───────╫────────╫───╫──┤ X ├─╫───────■──┤M├──|0>──╫───────────╫──»
# «                  ║        ║   ║  └───┘ ║          └╥┘       ║           ║  »
# «  c_bit: 6/═══════╩════════╩═══╩════════╩═══════════╩════════╬═══════════╬══»
# «                  0        4   3        1           5        ║           ║  »
# «c_phase: 2/══════════════════════════════════════════════════╩═══════════╩══»
# «                                                             0           1  »
# «           ┌───┐┌─┐
# «      q_0: ┤ H ├┤M├
# «           └───┘└╥┘
# «      q_1: ──────╫─
# «                 ║
# «      q_2: ──────╫─
# «                 ║
# «      q_3: ──────╫─
# «                 ║
# «      q_4: ──────╫─
# «                 ║
# «      q_5: ──────╫─
# «                 ║
# «      q_6: ─|0>──╫─
# «                 ║
# «      q_7: ──────╫─
# «                 ║
# «      q_8: ──────╫─
# «                 ║
# «  c_bit: 6/══════╩═
# «                 0
# «c_phase: 2/════════
# «
# {'00 011001': 5, '00 000001': 14, '11 101001': 13, '01 101111': 9, '01 110101': 10, '11 001110': 9, '11 110000': 7, '10 000111': 9, '01 000110': 7, '00 001101': 11, '10 011100': 6, '10 111011': 7, '01 001011': 9, '11 101000': 7, '00 110001': 5, '01 111000': 6, '11 011001': 12, '10 001011': 9, '10 111000': 6, '01 111010': 6, '01 000100': 6, '10 001000': 8, '10 010000': 6, '00 000000': 3, '11 001111': 5, '00 111100': 12, '11 100111': 7, '11 100100': 10, '00 001110': 14, '10 011101': 6, '01 011100': 7, '11 000011': 9, '01 101101': 16, '11 110011': 10, '00 100111': 8, '01 100000': 4, '11 001100': 17, '00 100110': 6, '10 111010': 6, '11 010101': 8, '01 001001': 3, '11 100110': 12, '10 001001': 13, '11
000101': 14, '10 001010': 7, '11 010110': 7, '00 011000': 6, '11 000000': 6, '01 010011': 7, '01 010001': 6, '10 101110': 7, '11 101011': 4, '10 010001': 8, '11 010111': 9, '10 000110': 8, '10 100001': 13, '00 111110': 5, '10 100011': 6, '11 001101': 8, '10 100010': 4, '11 111101': 11, '01 010000': 4, '01 010010': 10, '00 101000': 7, '11 110001': 9, '00 101001': 4, '00 010111': 9, '01 011101': 5, '00 010110': 4, '10 000100': 12, '00 011010': 7, '11 010100': 9, '10 111001': 8, '10 010010': 6, '11 000001': 14, '01 000111': 5, '01 100011': 9, '11 111100': 6, '11 110010': 8, '00 100100': 5, '11 100101': 6, '01 000101': 6, '00 110011': 10, '00 011011': 10, '10 101101': 5, '00 111101': 5, '00 110000': 8, '11 011011': 8, '11 111110': 5, '01 101110': 3, '00 100101': 7, '10 101100': 5, '00 010101': 10, '10 011111': 15, '10 110100': 8, '00 110010': 3, '11 011010': 3}
# Bit-flip syndrome: 011001, Phase-flip syndrome: 00
# Bit-flip syndrome: 000001, Phase-flip syndrome: 00
# Bit-flip syndrome: 101001, Phase-flip syndrome: 11
# Bit-flip syndrome: 101111, Phase-flip syndrome: 01
# Bit-flip syndrome: 110101, Phase-flip syndrome: 01
# Bit-flip syndrome: 001110, Phase-flip syndrome: 11
# Bit-flip syndrome: 110000, Phase-flip syndrome: 11
# Bit-flip syndrome: 000111, Phase-flip syndrome: 10
# Bit-flip syndrome: 000110, Phase-flip syndrome: 01
# Bit-flip syndrome: 001101, Phase-flip syndrome: 00
# Bit-flip syndrome: 011100, Phase-flip syndrome: 10
# Bit-flip syndrome: 111011, Phase-flip syndrome: 10
# Bit-flip syndrome: 001011, Phase-flip syndrome: 01
# Bit-flip syndrome: 101000, Phase-flip syndrome: 11
# Bit-flip syndrome: 110001, Phase-flip syndrome: 00
# Bit-flip syndrome: 111000, Phase-flip syndrome: 01
# Bit-flip syndrome: 011001, Phase-flip syndrome: 11
# Bit-flip syndrome: 001011, Phase-flip syndrome: 10
# Bit-flip syndrome: 111000, Phase-flip syndrome: 10
# Bit-flip syndrome: 111010, Phase-flip syndrome: 01
# Bit-flip syndrome: 000100, Phase-flip syndrome: 01
# Bit-flip syndrome: 001000, Phase-flip syndrome: 10
# Bit-flip syndrome: 010000, Phase-flip syndrome: 10
# Bit-flip syndrome: 000000, Phase-flip syndrome: 00
# Bit-flip syndrome: 001111, Phase-flip syndrome: 11
# Bit-flip syndrome: 111100, Phase-flip syndrome: 00
# Bit-flip syndrome: 100111, Phase-flip syndrome: 11
# Bit-flip syndrome: 100100, Phase-flip syndrome: 11
# Bit-flip syndrome: 001110, Phase-flip syndrome: 00
# Bit-flip syndrome: 011101, Phase-flip syndrome: 10
# Bit-flip syndrome: 011100, Phase-flip syndrome: 01
# Bit-flip syndrome: 000011, Phase-flip syndrome: 11
# Bit-flip syndrome: 010001, Phase-flip syndrome: 01
# Bit-flip syndrome: 101110, Phase-flip syndrome: 10
# Bit-flip syndrome: 101011, Phase-flip syndrome: 11
# Bit-flip syndrome: 010001, Phase-flip syndrome: 10
# Bit-flip syndrome: 010111, Phase-flip syndrome: 11
# Bit-flip syndrome: 000110, Phase-flip syndrome: 10
# Bit-flip syndrome: 100001, Phase-flip syndrome: 10
# Bit-flip syndrome: 111110, Phase-flip syndrome: 00
# Bit-flip syndrome: 100011, Phase-flip syndrome: 10
# Bit-flip syndrome: 001101, Phase-flip syndrome: 11
# Bit-flip syndrome: 100010, Phase-flip syndrome: 10
# Bit-flip syndrome: 111101, Phase-flip syndrome: 11
# Bit-flip syndrome: 010000, Phase-flip syndrome: 01
# Bit-flip syndrome: 010010, Phase-flip syndrome: 01
# Bit-flip syndrome: 101000, Phase-flip syndrome: 00
# Bit-flip syndrome: 110001, Phase-flip syndrome: 11
# Bit-flip syndrome: 101001, Phase-flip syndrome: 00
# Bit-flip syndrome: 010111, Phase-flip syndrome: 00
# Bit-flip syndrome: 011101, Phase-flip syndrome: 01
# Bit-flip syndrome: 010110, Phase-flip syndrome: 00
# Bit-flip syndrome: 000100, Phase-flip syndrome: 10
# Bit-flip syndrome: 011010, Phase-flip syndrome: 00
# Bit-flip syndrome: 010100, Phase-flip syndrome: 11
# Bit-flip syndrome: 111001, Phase-flip syndrome: 10
# Bit-flip syndrome: 010010, Phase-flip syndrome: 10
# Bit-flip syndrome: 000001, Phase-flip syndrome: 11
# Bit-flip syndrome: 000111, Phase-flip syndrome: 01
# Bit-flip syndrome: 100011, Phase-flip syndrome: 01
# Bit-flip syndrome: 111100, Phase-flip syndrome: 11
# Bit-flip syndrome: 110010, Phase-flip syndrome: 11
# Bit-flip syndrome: 100100, Phase-flip syndrome: 00
# Bit-flip syndrome: 100101, Phase-flip syndrome: 11
# Bit-flip syndrome: 000101, Phase-flip syndrome: 01
# Bit-flip syndrome: 110011, Phase-flip syndrome: 00
# Bit-flip syndrome: 011011, Phase-flip syndrome: 00
# Bit-flip syndrome: 101101, Phase-flip syndrome: 10
# Bit-flip syndrome: 111101, Phase-flip syndrome: 00
# Bit-flip syndrome: 110000, Phase-flip syndrome: 00
# Bit-flip syndrome: 011011, Phase-flip syndrome: 11
# Bit-flip syndrome: 111110, Phase-flip syndrome: 11
# Bit-flip syndrome: 101110, Phase-flip syndrome: 01
# Bit-flip syndrome: 100101, Phase-flip syndrome: 00
# Bit-flip syndrome: 101100, Phase-flip syndrome: 10
# Bit-flip syndrome: 010101, Phase-flip syndrome: 00
# Bit-flip syndrome: 011111, Phase-flip syndrome: 10
# Bit-flip syndrome: 110100, Phase-flip syndrome: 10
# Bit-flip syndrome: 110010, Phase-flip syndrome: 00
# Bit-flip syndrome: 011010, Phase-flip syndrome: 11
