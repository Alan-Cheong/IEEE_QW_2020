# %% [markdown]
# <a href="https://colab.research.google.com/github/Alan-Cheong/IEEE_QW_2020/blob/master/Semantic_Scholar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

base_url = "https://api.semanticscholar.org/datasets/v1/release/"

# This endpoint requires authentication via api key
api_key = "R2roMIaomx1W76DOR5neu3D3IRRiboA16DjbmiIO"
headers = {"x-api-key": api_key}

# Set the release id
release_id = "2023-10-31"

# Define dataset name you want to download
dataset_name = 'papers'

# Send the GET request and store the response in a variable
response = requests.get(base_url + release_id + '/dataset/' + dataset_name, headers=headers)

# Process and print the response data
print(response.json())
# Out:
# {'name': 'papers', 'description': 'The core attributes of a paper (title, authors, date, etc.).\n200M records in 30 1.5GB files.', 'README': 'Semantic Scholar Academic Graph Datasets\n\nThe "papers" dataset provides core metadata about papers.\n\nSCHEMA\nSee https://api.semanticscholar.org/api-docs/graph#tag/Paper-Data\n\nThis dataset does not contain information about a paper\'s references or citations.\nInstead, join with citingPaperId/citedPaperId from the "citations" dataset.\n\nLICENSE\nThis collection is licensed under ODC-BY. (https://opendatacommons.org/licenses/by/1.0/)\n\nBy downloading this data you acknowledge that you have read and agreed to all the terms in this license.\n\nATTRIBUTION\nWhen using this data in a product or service, or including data in a redistribution, please cite the following paper:\n\nBibTex format:\n@misc{https://doi.org/10.48550/arxiv.2301.10140,\n  title = {The Semantic Scholar Open Data Platform},\n  author = {Kinney, Rodney and Anastasiades, Ch
# ...

# %%
import requests
import json

# Specify the search term
query = '"generative ai"'

# Define the API endpoint URL
url = "http://api.semanticscholar.org/graph/v1/paper/search/bulk"

# Define the query parameters
query_params = {
    "query": '"generative ai"',
    "fields": "title,url,publicationTypes,publicationDate,openAccessPdf",
    "limit": "200",
    "year": "2025-"
}

# Directly define the API key (Reminder: Securely handle API keys in production environments)
api_key = "R2roMIaomx1W76DOR5neu3D3IRRiboA16DjbmiIO"  # Replace with the actual API key

# Define headers with API key
headers = {"x-api-key": api_key}

# Send the API request
response = requests.get(url, params=query_params, headers=headers).json()

# Print each item in the 'data' list on a new line
for item in response.get('data', []):
    print(item)
# Out:
# {'paperId': '00047d65de10100f2383698f4cfbf664cd755dea', 'url': 'https://www.semanticscholar.org/paper/00047d65de10100f2383698f4cfbf664cd755dea', 'title': 'AMD Instinct MI300X: A Generative AI Accelerator and Platform Architecture', 'openAccessPdf': {'url': '', 'status': None, 'license': None}, 'publicationTypes': ['JournalArticle'], 'publicationDate': '2025-05-01'}
# {'paperId': '00074c1a994727e3ed172237878cad40b67411a4', 'url': 'https://www.semanticscholar.org/paper/00074c1a994727e3ed172237878cad40b67411a4', 'title': 'Understanding the Challenges and Promises of Developing Generative AI Apps: An Empirical Study', 'openAccessPdf': {'url': '', 'status': None, 'license': None}, 'publicationTypes': ['JournalArticle', 'Review'], 'publicationDate': '2025-06-19'}
# ...
